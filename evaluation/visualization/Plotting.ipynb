# %% [markdown]
# ## This is for testing some things and should not be checked into VC

# %% [markdown]
# Todos:
# - kl-weight-scale auf dem loss bei der evaluation rausnehmen
# - große Netze weglassen, nur (10, ) und (7,7) bleiben

# %%
import pandas

# %%
df_bayes = pandas.read_csv('data/cluster/first_run_2019-06-05_18-08/results_bayesian_EconDensity.csv')

# %%
df_bayes.columns
# Out:
# Index(['Unnamed: 0', 'mean_fit_time', 'std_fit_time', 'mean_score_time',
#        'std_score_time', 'param_flow_types', 'param_hidden_sizes',
#        'param_kl_weight_scale', 'param_learning_rate', 'param_prior_scale',
#        'param_x_noise_std', 'param_y_noise_std', 'params', 'split0_test_score',
#        'split1_test_score', 'split2_test_score', 'split3_test_score',
#        'split4_test_score', 'mean_test_score', 'std_test_score',
#        'rank_test_score'],
#       dtype='object')

# %%
df_bayes.sort_values("rank_test_score")
# Out:
#     Unnamed: 0  Unnamed: 0.1  mean_fit_time  std_fit_time  mean_score_time  \
# 32           5             5     118.226239      0.690327         0.828444
# 4            4             4     121.346832      0.974374         0.725490
# 18           0             0     117.206911      1.530346         0.724612
# 14           5             5     120.252180      1.067985         0.782060
# 19           1             1     120.637570      1.700767         0.749994
# 8            8             8      96.327886      1.744021         0.480843
# 29           2             2     119.365097      0.842402         0.694883
# 15           6             6     118.952203      1.229266         0.801980
# 17           8             8      94.619785      1.736284         0.452174
# 30           3             3     118.091087      0.618917         0.733954
# 20           2             2     119.194946      2.135291         0.777315
# ...

# %%
for param in ['param_hidden_sizes', 'param_learning_rate', 'param_x_noise_std', 'param_y_noise_std', 'param_kl_weight_scale']:
    for df in [df_bayes]:
        print(param)
        print()
        print(df_bayes.groupby(param)['mean_test_score', 'std_test_score', 'rank_test_score'].mean())
        print()
# Out:
# param_hidden_sizes
#
#                     mean_test_score  std_test_score  rank_test_score
# param_hidden_sizes
# (10,)                      0.428858        0.415951        63.078125
# (20,)                 -14848.688583    20921.607998       139.250000
# (7, 7)                     0.416895        0.113090        87.171875
#
# param_learning_rate
#
#                      mean_test_score  std_test_score  rank_test_score
# param_learning_rate
# 0.003                   -9897.692349    13946.437246       103.760417
# 0.020                      -0.869539        1.654113        89.239583
#
# param_x_noise_std
#
#                    mean_test_score  std_test_score  rank_test_score
# param_x_noise_std
# 0.0                  -19102.040081    26989.467639        96.604167
# 0.1                    -167.804277      213.181914        92.812500
# 0.2                    -226.212312      301.144933        96.437500
# 0.4                    -301.067104      392.388233       100.145833
#
# ...

# %%
df_mle = pandas.read_csv('/home/simon/Documents/KIT/Informatik/Bachelorarbeit/VI/data/local/skew_run_2019-06-04_17-05/results_mle_SkewNormal.csv')

# %%
df_mle.sort_values("rank_test_score")
# Out:
#    Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6           6      76.298430      2.438559         0.497186        0.072369
# 5           5      88.345978     16.223454         0.508825        0.054691
# 8           8      64.995817      6.606883         0.439320        0.068307
# 2           2      64.424318      0.438851         0.514917        0.093805
# 3           3      65.011397      0.089236         0.521880        0.063526
# 7           7      74.841977      1.105227         0.463498        0.071505
# 1           1      64.858335      0.530319         0.438004        0.048234
# 0           0      65.832714      0.732929         0.485081        0.041748
# 4           4      65.094759      0.208773         0.572632        0.063536
#
#   param_activation                param_flow_types param_hidden_sizes  \
# 6             tanh  ['radial', 'radial', 'radial']               [10]
# ...

# %%
for param in ['param_hidden_sizes', 'param_x_noise_std', 'param_y_noise_std']:
    for df in [df_mle]:
        print(param)
        print()
        print(df_mle.groupby(param)['mean_test_score', 'std_test_score', 'rank_test_score'].mean())
        print()
# Out:
# param_hidden_sizes
#
#                     mean_test_score  std_test_score  rank_test_score
# param_hidden_sizes
# [10]                       1.564145        0.013899                5
#
# param_x_noise_std
#
#                    mean_test_score  std_test_score  rank_test_score
# param_x_noise_std
# 0.0                       1.558426        0.013199         6.333333
# 0.1                       1.563108        0.018299         5.333333
# 0.2                       1.570900        0.010200         3.333333
#
# param_y_noise_std
#
#                    mean_test_score  std_test_score  rank_test_score
# param_y_noise_std
# 0.00                      1.563512        0.017025         4.666667
# 0.01                      1.554869        0.011106         7.333333
# 0.10                      1.574054        0.013567         3.000000
